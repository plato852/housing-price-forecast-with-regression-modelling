# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
import math

# %%
import os
os.chdir('/Users/platong/Downloads')

# %%
oxford_data = pd.read_csv('oxford.csv')
marlow_data = pd.read_csv('marlow.csv')
chichester_data = pd.read_csv('chichester.csv')
winchester_data = pd.read_csv('winchester.csv')
guilford_data = pd.read_csv('guilford.csv')
henley_data = pd.read_csv('henley.csv')
brighton_data = pd.read_csv('brighton.csv')
reading_data = pd.read_csv('reading.csv')
southampton_data = pd.read_csv('southampton.csv')
canterbury_data = pd.read_csv('canterbury.csv')

# %%
housing_data_full = pd.concat([oxford_data,marlow_data,chichester_data,winchester_data,guilford_data,henley_data,brighton_data,reading_data,southampton_data,canterbury_data
])

# %%
housing_data_full
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0       1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1       1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2       1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3       1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4       1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..               ...                                                ...
# 0       1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 1       1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 2       1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 3       1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 4       1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                          listing_link  \
# 0   loadingloadingloadingloadingloadingloadingload...
# 1   loadingloadingloadingloadingloadingloadingload...
# 2   loadingloadingloadingloadingloadingloadingload...
# 3   loadingloadingloadingloadingloadingloadingload...
# 4   loadingloadingloadingloadingloadingloadingload...
# ..                                                ...
# 0   loadingloadingloadingloadingloadingloadingload...
# 1   loadingloadingloadingloadingloadingloadingload...
# 2   loadingloadingloadingloadingloadingloadingload...
# 3   loadingloadingloadingloadingloadingloadingload...
# 4   loadingloadingloadingloadingloadingloadingload...
#
#                                     listing_link-href       price     no_bed  \
# 0   https://search.savills.com/property-detail/gbs...  £1,500,000  4Bedrooms
# 1   https://search.savills.com/property-detail/gbs...  £1,600,000  5Bedrooms
# 2   https://search.savills.com/property-detail/gbs...  £1,050,000  5Bedrooms
# 3   https://search.savills.com/property-detail/gbs...    £900,000  5Bedrooms
# 4   https://search.savills.com/property-detail/gbs...  £1,300,000  5Bedrooms
# ..                                                ...         ...        ...
# 0   https://search.savills.com/com/en/property-det...  £1,200,000  5Bedrooms
# 1   https://search.savills.com/com/en/property-det...    £850,000  4Bedrooms
# 2   https://search.savills.com/com/en/property-det...  £1,000,000  4Bedrooms
# 3   https://search.savills.com/com/en/property-det...    £750,000  4Bedrooms
# 4   https://search.savills.com/com/en/property-det...  £2,950,000  5Bedrooms
#
#        no_bath       no_rec                       size   type  \
# 0   4Bathrooms  3Receptions  3,162 sq ft (293.76 sq m)  House
# 1   3Bathrooms  2Receptions  2,050 sq ft (190.45 sq m)  House
# 2   2Bathrooms  4Receptions  2,031 sq ft (188.69 sq m)  House
# 3   2Bathrooms  2Receptions  2,124 sq ft (197.33 sq m)  House
# 4   4Bathrooms  2Receptions  3,110 sq ft (288.93 sq m)  House
# ..         ...          ...                        ...    ...
# 0   3Bathrooms  2Receptions  302.21 sq m (3,253 sq ft)  House
# 1   2Bathrooms  3Receptions  144.93 sq m (1,560 sq ft)  House
# 2   2Bathrooms  3Receptions  238.85 sq m (2,571 sq ft)  House
# 3   2Bathrooms  2Receptions  217.67 sq m (2,343 sq ft)  House
# 4   5Bathrooms  4Receptions  445.10 sq m (4,791 sq ft)  House
#
#                                          address            EPC  Unnamed: 12  \
# 0   Great Haseley, Oxford, Oxfordshire, OX44 7JG  EPC Rating: D          NaN
# 1                   Oxford, Oxfordshire, OX2 7QB  EPC Rating: C          NaN
# 2                   Oxford, Oxfordshire, OX2 8HX  EPC Rating: E          NaN
# 3      Garsington, Oxford, Oxfordshire, OX44 9DJ  EPC Rating: D          NaN
# 4                  Oxford, Oxfordshire, OX33 1AY  EPC Rating: D          NaN
# ..                                           ...            ...          ...
# 0          Hastingleigh, Ashford, Kent, TN25 5JE  EPC Rating: D          NaN
# 1               Elham, Canterbury, Kent, CT4 6TE  EPC Rating: F          NaN
# 2              Staple, Canterbury, Kent, CT3 1NX  EPC Rating: C          NaN
# 3             Wingham, Canterbury, Kent, CT3 1BJ  EPC Rating: E          NaN
# 4                      Whitstable, Kent, CT5 2BQ  EPC Rating: C          NaN
#
#     Unnamed: 13
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [114 rows x 14 columns]

# %% [markdown]
# # Data Cleaning & Transformming

# %%
housing_data_full['price'] = housing_data_full['price'].str.replace('£','')
housing_data_full['price'] = housing_data_full['price'].str.replace(',','')
housing_data_full['price'] = housing_data_full['price'].apply(pd.to_numeric)

housing_data_full['no_bed'] = housing_data_full['no_bed'].str.replace('Bedrooms','')
housing_data_full['no_bed'] = housing_data_full['no_bed'].apply(pd.to_numeric)

housing_data_full['no_bath'] = housing_data_full['no_bath'].str.replace('Bathrooms','')
housing_data_full['no_bath'] = housing_data_full['no_bath'].apply(pd.to_numeric)

housing_data_full['no_rec'] = housing_data_full['no_rec'].str.replace('Receptions','')
housing_data_full['no_rec'] = housing_data_full['no_rec'].apply(pd.to_numeric)

housing_data_full['sqft'] = housing_data_full['size'].str.extract(r'([\d,]+) sq ft')
housing_data_full['sqft'] = housing_data_full['sqft'].str.replace(',','')
housing_data_full['sqft'] = housing_data_full['sqft'].apply(pd.to_numeric)
housing_data_full.drop(columns=['size'], inplace=True)

housing_data_full.drop(columns=['Unnamed: 12'], inplace=True)
housing_data_full.drop(columns=['Unnamed: 13'], inplace=True)
housing_data_full.drop(columns=['listing_link'], inplace=True)


housing_data_full['EPC'] = housing_data_full['EPC'].str.replace('EPC Rating:', '').str.extract(r'(\b\w+\b)').astype(str)

# %%
housing_data_full
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0       1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1       1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2       1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3       1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4       1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..               ...                                                ...
# 0       1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 1       1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 2       1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 3       1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 4       1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                     listing_link-href    price  no_bed  \
# 0   https://search.savills.com/property-detail/gbs...  1500000       4
# 1   https://search.savills.com/property-detail/gbs...  1600000       5
# 2   https://search.savills.com/property-detail/gbs...  1050000       5
# 3   https://search.savills.com/property-detail/gbs...   900000       5
# 4   https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                ...      ...     ...
# 0   https://search.savills.com/com/en/property-det...  1200000       5
# 1   https://search.savills.com/com/en/property-det...   850000       4
# 2   https://search.savills.com/com/en/property-det...  1000000       4
# 3   https://search.savills.com/com/en/property-det...   750000       4
# 4   https://search.savills.com/com/en/property-det...  2950000       5
#
#     no_bath  no_rec   type                                       address EPC  \
# 0         4       3  House  Great Haseley, Oxford, Oxfordshire, OX44 7JG   D
# 1         3       2  House                  Oxford, Oxfordshire, OX2 7QB   C
# 2         2       4  House                  Oxford, Oxfordshire, OX2 8HX   E
# 3         2       2  House     Garsington, Oxford, Oxfordshire, OX44 9DJ   D
# 4         4       2  House                 Oxford, Oxfordshire, OX33 1AY   D
# ..      ...     ...    ...                                           ...  ..
# 0         3       2  House         Hastingleigh, Ashford, Kent, TN25 5JE   D
# 1         2       3  House              Elham, Canterbury, Kent, CT4 6TE   F
# 2         2       3  House             Staple, Canterbury, Kent, CT3 1NX   C
# 3         2       2  House            Wingham, Canterbury, Kent, CT3 1BJ   E
# 4         5       4  House                     Whitstable, Kent, CT5 2BQ   C
#
#     sqft
# 0   3162
# 1   2050
# 2   2031
# 3   2124
# 4   3110
# ..   ...
# 0   3253
# 1   1560
# 2   2571
# 3   2343
# 4   4791
#
# [114 rows x 11 columns]

# %% [markdown]
# ## Adding new columns

# %% [markdown]
# ### Price per sq ft (£/sq ft)

# %%
housing_data_full['price_sqft'] = housing_data_full['price'] / housing_data_full['sqft']
housing_data_full['price_sqft'] = housing_data_full['price_sqft'].astype(float)
#Round up the values in 'price_sqft' column to the nearest integer:
housing_data_full['price_sqft'] = housing_data_full['price_sqft'].apply(lambda x: math.ceil(x)) 
housing_data_full['price_sqft'] = housing_data_full['price_sqft'].astype(str) + ' £/sqft'

# %%
housing_data_full.rename(columns={'type': 'property_type'}, inplace=True)

# %%
housing_data_full
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0       1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1       1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2       1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3       1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4       1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..               ...                                                ...
# 0       1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 1       1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 2       1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 3       1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 4       1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                     listing_link-href    price  no_bed  \
# 0   https://search.savills.com/property-detail/gbs...  1500000       4
# 1   https://search.savills.com/property-detail/gbs...  1600000       5
# 2   https://search.savills.com/property-detail/gbs...  1050000       5
# 3   https://search.savills.com/property-detail/gbs...   900000       5
# 4   https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                ...      ...     ...
# 0   https://search.savills.com/com/en/property-det...  1200000       5
# 1   https://search.savills.com/com/en/property-det...   850000       4
# 2   https://search.savills.com/com/en/property-det...  1000000       4
# 3   https://search.savills.com/com/en/property-det...   750000       4
# 4   https://search.savills.com/com/en/property-det...  2950000       5
#
#     no_bath  no_rec property_type  \
# 0         4       3         House
# 1         3       2         House
# 2         2       4         House
# 3         2       2         House
# 4         4       2         House
# ..      ...     ...           ...
# 0         3       2         House
# 1         2       3         House
# 2         2       3         House
# 3         2       2         House
# 4         5       4         House
#
#                                          address EPC  sqft  price_sqft
# 0   Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  3162  475 £/sqft
# 1                   Oxford, Oxfordshire, OX2 7QB   C  2050  781 £/sqft
# 2                   Oxford, Oxfordshire, OX2 8HX   E  2031  517 £/sqft
# 3      Garsington, Oxford, Oxfordshire, OX44 9DJ   D  2124  424 £/sqft
# 4                  Oxford, Oxfordshire, OX33 1AY   D  3110  419 £/sqft
# ..                                           ...  ..   ...         ...
# 0          Hastingleigh, Ashford, Kent, TN25 5JE   D  3253  369 £/sqft
# 1               Elham, Canterbury, Kent, CT4 6TE   F  1560  545 £/sqft
# 2              Staple, Canterbury, Kent, CT3 1NX   C  2571  389 £/sqft
# 3             Wingham, Canterbury, Kent, CT3 1BJ   E  2343  321 £/sqft
# 4                      Whitstable, Kent, CT5 2BQ   C  4791  616 £/sqft
#
# [114 rows x 12 columns]

# %% [markdown]
# ### City

# %%
city_data = pd.read_csv('city.csv')
housing_data_full = pd.read_csv('housing_data_full.csv')
housing_data_full['city'] = city_data['City']
housing_data_full.rename(columns={'city': 'City'}, inplace=True)

# %%
housing_data_full
# Out:
#      Unnamed: 0 web-scraper-order  \
# 0             0      1710807522-1
# 1             1      1710807524-2
# 2             2      1710807526-3
# 3             3      1710807528-4
# 4             4      1710807530-5
# ..          ...               ...
# 109         109      1710857925-3
# 110         110      1710857928-4
# 111         111      1710857931-5
# 112         112      1710857933-6
# 113         113      1710857936-7
#
#                                  web-scraper-start-url  \
# 0    https://search.savills.com/list?SearchList=Id_...
# 1    https://search.savills.com/list?SearchList=Id_...
# 2    https://search.savills.com/list?SearchList=Id_...
# 3    https://search.savills.com/list?SearchList=Id_...
# 4    https://search.savills.com/list?SearchList=Id_...
# ..                                                 ...
# 109  https://search.savills.com/com/en/list?SearchL...
# 110  https://search.savills.com/com/en/list?SearchL...
# 111  https://search.savills.com/com/en/list?SearchL...
# 112  https://search.savills.com/com/en/list?SearchL...
# 113  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href    price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000       4
# 1    https://search.savills.com/property-detail/gbs...  1600000       5
# 2    https://search.savills.com/property-detail/gbs...  1050000       5
# 3    https://search.savills.com/property-detail/gbs...   900000       5
# 4    https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                 ...      ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000       5
# 110  https://search.savills.com/com/en/property-det...   850000       4
# 111  https://search.savills.com/com/en/property-det...  1000000       4
# 112  https://search.savills.com/com/en/property-det...   750000       4
# 113  https://search.savills.com/com/en/property-det...  2950000       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  sqft  price_sqft  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  3162  475 £/sqft
# 1                    Oxford, Oxfordshire, OX2 7QB   C  2050  781 £/sqft
# 2                    Oxford, Oxfordshire, OX2 8HX   E  2031  517 £/sqft
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  2124  424 £/sqft
# 4                   Oxford, Oxfordshire, OX33 1AY   D  3110  419 £/sqft
# ..                                            ...  ..   ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  3253  369 £/sqft
# 110              Elham, Canterbury, Kent, CT4 6TE   F  1560  545 £/sqft
# 111             Staple, Canterbury, Kent, CT3 1NX   C  2571  389 £/sqft
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  2343  321 £/sqft
# 113                     Whitstable, Kent, CT5 2BQ   C  4791  616 £/sqft
#
#            City
# 0        Oxford
# 1        Oxford
# 2        Oxford
# 3        Oxford
# 4        Oxford
# ..          ...
# 109  Canterbury
# 110  Canterbury
# 111  Canterbury
# 112  Canterbury
# 113  Canterbury
#
# [114 rows x 14 columns]

# %%
housing_data_full.to_excel("housing_data_full.xlsx")

# %% [markdown]
# ### Population & Median values

# %%
city_stats_dict = [
    {'City': 'Oxford', 'City_population': 182100, 'City_med_income': 38800, 'City_med_age': 30},
    {'City': 'Henley', 'City_population': 11782, 'City_med_income': 36500, 'City_med_age': 31.1},
    {'City': 'Marlow', 'City_population': 14644, 'City_med_income': 43500, 'City_med_age': 42.0},
    {'City': 'Southampton', 'City_population': 286561, 'City_med_income': 37000, 'City_med_age': 34},
    {'City': 'Winchester', 'City_population': 127500, 'City_med_income': 31276, 'City_med_age': 42},
    {'City': 'Chichester', 'City_population': 124100, 'City_med_income': 31800, 'City_med_age': 47},
    {'City': 'Brighton', 'City_population': 276300, 'City_med_income': 34900, 'City_med_age': 36.5},
    {'City': 'Canterbury', 'City_population': 157400, 'City_med_income': 32900, 'City_med_age': 40},
    {'City': 'Reading', 'City_population': 174224, 'City_med_income': 40600, 'City_med_age': 34},
    {'City': 'Guildford', 'City_population': 143649, 'City_med_income': 43300, 'City_med_age': 38.5}
]

city_stats = pd.DataFrame(city_stats_dict)

# %%
city_stats
# Out:
#           City  City_population  City_med_income  City_med_age
# 0       Oxford           182100            38800          30.0
# 1       Henley            11782            36500          31.1
# 2       Marlow            14644            43500          42.0
# 3  Southampton           286561            37000          34.0
# 4   Winchester           127500            31276          42.0
# 5   Chichester           124100            31800          47.0
# 6     Brighton           276300            34900          36.5
# 7   Canterbury           157400            32900          40.0
# 8      Reading           174224            40600          34.0
# 9    Guildford           143649            43300          38.5

# %%
city_stats.dtypes
# Out:
# City                object
# City_population      int64
# City_med_income      int64
# City_med_age       float64
# dtype: object

# %%
housing_data_full['City'].dtypes == city_stats['City'].dtypes
housing_data_full['City'] = housing_data_full['City'].astype(str)
housing_data_full['City'] = housing_data_full['City'].str.strip()
updated_housing_data = pd.merge(housing_data_full, city_stats, on='City', how='left')
updated_housing_data
# Out:
#      Unnamed: 0 web-scraper-order  \
# 0             0      1710807522-1
# 1             1      1710807524-2
# 2             2      1710807526-3
# 3             3      1710807528-4
# 4             4      1710807530-5
# ..          ...               ...
# 109         109      1710857925-3
# 110         110      1710857928-4
# 111         111      1710857931-5
# 112         112      1710857933-6
# 113         113      1710857936-7
#
#                                  web-scraper-start-url  \
# 0    https://search.savills.com/list?SearchList=Id_...
# 1    https://search.savills.com/list?SearchList=Id_...
# 2    https://search.savills.com/list?SearchList=Id_...
# 3    https://search.savills.com/list?SearchList=Id_...
# 4    https://search.savills.com/list?SearchList=Id_...
# ..                                                 ...
# 109  https://search.savills.com/com/en/list?SearchL...
# 110  https://search.savills.com/com/en/list?SearchL...
# 111  https://search.savills.com/com/en/list?SearchL...
# 112  https://search.savills.com/com/en/list?SearchL...
# 113  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href    price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000       4
# 1    https://search.savills.com/property-detail/gbs...  1600000       5
# 2    https://search.savills.com/property-detail/gbs...  1050000       5
# 3    https://search.savills.com/property-detail/gbs...   900000       5
# 4    https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                 ...      ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000       5
# 110  https://search.savills.com/com/en/property-det...   850000       4
# 111  https://search.savills.com/com/en/property-det...  1000000       4
# 112  https://search.savills.com/com/en/property-det...   750000       4
# 113  https://search.savills.com/com/en/property-det...  2950000       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  sqft  price_sqft  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  3162  475 £/sqft
# 1                    Oxford, Oxfordshire, OX2 7QB   C  2050  781 £/sqft
# 2                    Oxford, Oxfordshire, OX2 8HX   E  2031  517 £/sqft
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  2124  424 £/sqft
# 4                   Oxford, Oxfordshire, OX33 1AY   D  3110  419 £/sqft
# ..                                            ...  ..   ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  3253  369 £/sqft
# 110              Elham, Canterbury, Kent, CT4 6TE   F  1560  545 £/sqft
# 111             Staple, Canterbury, Kent, CT3 1NX   C  2571  389 £/sqft
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  2343  321 £/sqft
# 113                     Whitstable, Kent, CT5 2BQ   C  4791  616 £/sqft
#
#            City  City_population  City_med_income  City_med_age
# 0        Oxford           182100            38800          30.0
# 1        Oxford           182100            38800          30.0
# 2        Oxford           182100            38800          30.0
# 3        Oxford           182100            38800          30.0
# 4        Oxford           182100            38800          30.0
# ..          ...              ...              ...           ...
# 109  Canterbury           157400            32900          40.0
# 110  Canterbury           157400            32900          40.0
# 111  Canterbury           157400            32900          40.0
# 112  Canterbury           157400            32900          40.0
# 113  Canterbury           157400            32900          40.0
#
# [114 rows x 17 columns]

# %% [markdown]
# ### Postcode (extract from address)

# %%
updated_housing_data['postcode'] = updated_housing_data['address'].str.split(',').str[-1].str.strip()

# %%
updated_housing_data.drop(columns=['Unnamed: 0'], inplace=True)
updated_housing_data
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1        1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2        1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3        1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4        1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..                ...                                                ...
# 109      1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 110      1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 111      1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 112      1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 113      1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href    price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000       4
# 1    https://search.savills.com/property-detail/gbs...  1600000       5
# 2    https://search.savills.com/property-detail/gbs...  1050000       5
# 3    https://search.savills.com/property-detail/gbs...   900000       5
# 4    https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                 ...      ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000       5
# 110  https://search.savills.com/com/en/property-det...   850000       4
# 111  https://search.savills.com/com/en/property-det...  1000000       4
# 112  https://search.savills.com/com/en/property-det...   750000       4
# 113  https://search.savills.com/com/en/property-det...  2950000       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  sqft  price_sqft  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  3162  475 £/sqft
# 1                    Oxford, Oxfordshire, OX2 7QB   C  2050  781 £/sqft
# 2                    Oxford, Oxfordshire, OX2 8HX   E  2031  517 £/sqft
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  2124  424 £/sqft
# 4                   Oxford, Oxfordshire, OX33 1AY   D  3110  419 £/sqft
# ..                                            ...  ..   ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  3253  369 £/sqft
# 110              Elham, Canterbury, Kent, CT4 6TE   F  1560  545 £/sqft
# 111             Staple, Canterbury, Kent, CT3 1NX   C  2571  389 £/sqft
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  2343  321 £/sqft
# 113                     Whitstable, Kent, CT5 2BQ   C  4791  616 £/sqft
#
#            City  City_population  City_med_income  City_med_age  postcode
# 0        Oxford           182100            38800          30.0  OX44 7JG
# 1        Oxford           182100            38800          30.0   OX2 7QB
# 2        Oxford           182100            38800          30.0   OX2 8HX
# 3        Oxford           182100            38800          30.0  OX44 9DJ
# 4        Oxford           182100            38800          30.0  OX33 1AY
# ..          ...              ...              ...           ...       ...
# 109  Canterbury           157400            32900          40.0  TN25 5JE
# 110  Canterbury           157400            32900          40.0   CT4 6TE
# 111  Canterbury           157400            32900          40.0   CT3 1NX
# 112  Canterbury           157400            32900          40.0   CT3 1BJ
# 113  Canterbury           157400            32900          40.0   CT5 2BQ
#
# [114 rows x 17 columns]

# %% [markdown]
# ### Distance to city centre

# %% [markdown]
# #### There are tons of ways to find out the distances between two sets of coordinates globally on the internet, here I used [freemaptools.com](https://www.freemaptools.com/)
# #### which allowed me to easily use a point-and-click interface to gather the coordinates data (lon,lat) for each postal codes.
# #### The outputs from the website allow me to copy and paste directly to the updated_housing_data spreadsheet then work on the calculation.

# %% [markdown]
# ##### Coordinates of the property:

# %%
coordinates = [
    (51.71151, -1.07196),
    (51.78252, -1.26003),
    (51.78994, -1.27929),
    (51.71269, -1.15480),
    (51.80730, -1.13764),
    (51.76974, -1.22622),
    (51.76662, -1.25754),
    (51.76831, -1.27168),
    (51.63553, -1.39563),
    (51.78558, -1.27520),
    (51.74838, -1.22283),
    (51.75642, -1.26451),
    (51.74171, -1.28752),
    (51.78463, -1.27756),
    (51.56716, -0.78719),
    (51.55879, -0.86977),
    (51.56875, -0.78847),
    (51.58346, -0.82599),
    (51.58244, -0.76709),
    (51.52882, -0.70659),
    (51.56927, -0.76652),
    (51.57281, -0.69396),
    (51.56539, -0.73836),
    (51.53005, -0.70276),
    (51.57765, -0.75075),
    (51.57617, -0.77532),
    (51.52950, -0.75988),
    (51.61105, -0.83739),
    (51.56220, -0.74389),
    (50.94869, -0.62322),
    (50.94869, -0.62322),
    (50.82192, -0.61738),
    (50.99819, -0.73518),
    (50.95422, -0.68050),
    (50.95418, -0.75092),
    (50.98104, -0.61295),
    (51.01812, -0.74800),
    (50.82535, -0.85622),
    (50.98275, -0.60902),
    (50.95665, -0.78202),
    (51.25943, -1.62348),
    (50.90603, -1.21082),
    (51.06556, -1.33765),
    (51.01079, -1.65624),
    (51.11049, -0.98238),
    (51.16559, -1.23514),
    (51.06942, -1.33480),
    (51.27202, -1.51654),
    (51.03072, -1.64887),
    (51.05706, -1.32185),
    (51.00180, -1.40909),
    (51.11075, -1.29982),
    (51.24381, -0.53249),
    (51.23288, -0.58370),
    (51.19306, -0.65091),
    (51.27159, -0.37195),
    (51.23640, -0.56593),
    (51.24224, -0.54997),
    (51.22991, -0.56403),
    (51.34603, -0.45645),
    (51.14483, -0.63497),
    (51.13295, -0.63172),
    (51.25848, -0.45324),
    (51.13561, -0.62027),
    (51.24194, -0.54933),
    (51.34576, -0.45894),
    (51.54177, -0.66670),
    (51.52618, -0.93293),
    (51.53584, -0.90221),
    (51.61105, -0.83739),
    (51.50139, -0.86667),
    (51.52450, -0.98731),
    (51.53222, -0.99527),
    (51.59996, -0.66560),
    (51.53548, -0.90098),
    (51.57281, -0.69396),
    (51.51950, -0.69573),
    (50.93655, -0.25016),
    (50.91509, -0.23628),
    (50.81598, -0.10039),
    (50.93256, -0.16267),
    (50.88881, 0.02145),
    (50.93505, -0.07640),
    (50.92568, -0.01252),
    (50.91251, -0.06121),
    (50.92724, -0.05811),
    (50.89586, -0.20612),
    (50.92117, 0.02603),
    (51.52371, -0.98104),
    (51.47982, -0.92322),
    (51.43336, -0.97608),
    (51.51112, -1.02260),
    (51.50288, -0.92367),
    (51.51032, -1.02392),
    (51.50099, -0.89941),
    (51.46028, -0.85788),
    (51.50081, -0.92537),
    (51.52450, -0.98731),
    (51.01538, -1.33316),
    (50.85778, -1.31347),
    (51.02289, -1.33589),
    (51.00772, -1.26923),
    (51.02074, -1.34366),
    (51.01724, -1.33499),
    (50.99727, -1.37479),
    (50.89224, -1.31439),
    (51.00953, -1.40749),
    (50.90603, -1.21082),
    (50.92126, -1.23899),
    (51.17974, 0.98949),
    (51.15305, 1.11054),
    (51.26407, 1.26608),
    (51.27362, 1.21476),
    (51.36445, 1.03738)
]
latitudes = [coord[0] for coord in coordinates]
longitudes = [coord[1] for coord in coordinates]

updated_housing_data['prop_lat'] = latitudes
updated_housing_data['prop_lon'] = longitudes

# %%
centre_coor_dict = [
    {
    'City': 'Oxford',
    'Centre_lat': 51.7536512,
    'Centre_lon': -1.2761259
},
{
    'City': 'Marlow',
    'Centre_lat': 51.5724424,
    'Centre_lon': -0.7979936
},
{
    'City': 'Chichester',
    'Centre_lat': 50.8360691,
    'Centre_lon': -0.8199946
},
{
    'City': 'Winchester',
    'Centre_lat': 51.0534603,
    'Centre_lon': -1.3410619
},
{
    'City': 'Guildford',
    'Centre_lat': 51.2415081,
    'Centre_lon': -0.6067087
},
{
    'City': 'Henley',
    'Centre_lat': 51.536223,
    'Centre_lon': -0.903912
},
{
    'City': 'Brighton',
    'Centre_lat': 50.825584,
    'Centre_lon': -0.1594777
},
{
    'City': 'Reading',
    'Centre_lat': 51.455654,
    'Centre_lon': -0.973449
},
{
    'City': 'Southampton',
    'Centre_lat': 50.903268,
    'Centre_lon': -1.404810
},
{
    'City': 'Canterbury',
    'Centre_lat': 51.2796426,
    'Centre_lon': 1.0697729
}
]

city_centre_coor = pd.DataFrame(centre_coor_dict)

# %%
city_centre_coor
# Out:
#           City  Centre_lat  Centre_lon
# 0       Oxford   51.753651   -1.276126
# 1       Marlow   51.572442   -0.797994
# 2   Chichester   50.836069   -0.819995
# 3   Winchester   51.053460   -1.341062
# 4    Guildford   51.241508   -0.606709
# 5       Henley   51.536223   -0.903912
# 6     Brighton   50.825584   -0.159478
# 7      Reading   51.455654   -0.973449
# 8  Southampton   50.903268   -1.404810
# 9   Canterbury   51.279643    1.069773

# %%
updated_housing_data['City'].dtypes == city_centre_coor['City'].dtypes
updated_housing_data['City'] = updated_housing_data['City'].astype(str)
updated_housing_data['City'] = updated_housing_data['City'].str.strip()
updated_housing_data1 = pd.merge(updated_housing_data, city_centre_coor, on='City', how='left')
updated_housing_data1
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1        1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2        1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3        1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4        1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..                ...                                                ...
# 109      1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 110      1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 111      1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 112      1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 113      1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href    price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000       4
# 1    https://search.savills.com/property-detail/gbs...  1600000       5
# 2    https://search.savills.com/property-detail/gbs...  1050000       5
# 3    https://search.savills.com/property-detail/gbs...   900000       5
# 4    https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                 ...      ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000       5
# 110  https://search.savills.com/com/en/property-det...   850000       4
# 111  https://search.savills.com/com/en/property-det...  1000000       4
# 112  https://search.savills.com/com/en/property-det...   750000       4
# 113  https://search.savills.com/com/en/property-det...  2950000       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  ...  price_sqft  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  ...  475 £/sqft
# 1                    Oxford, Oxfordshire, OX2 7QB   C  ...  781 £/sqft
# 2                    Oxford, Oxfordshire, OX2 8HX   E  ...  517 £/sqft
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  ...  424 £/sqft
# 4                   Oxford, Oxfordshire, OX33 1AY   D  ...  419 £/sqft
# ..                                            ...  ..  ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  ...  369 £/sqft
# 110              Elham, Canterbury, Kent, CT4 6TE   F  ...  545 £/sqft
# 111             Staple, Canterbury, Kent, CT3 1NX   C  ...  389 £/sqft
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  ...  321 £/sqft
# 113                     Whitstable, Kent, CT5 2BQ   C  ...  616 £/sqft
#
#            City City_population  City_med_income  City_med_age  postcode  \
# 0        Oxford          182100            38800          30.0  OX44 7JG
# 1        Oxford          182100            38800          30.0   OX2 7QB
# 2        Oxford          182100            38800          30.0   OX2 8HX
# 3        Oxford          182100            38800          30.0  OX44 9DJ
# 4        Oxford          182100            38800          30.0  OX33 1AY
# ..          ...             ...              ...           ...       ...
# 109  Canterbury          157400            32900          40.0  TN25 5JE
# 110  Canterbury          157400            32900          40.0   CT4 6TE
# 111  Canterbury          157400            32900          40.0   CT3 1NX
# 112  Canterbury          157400            32900          40.0   CT3 1BJ
# 113  Canterbury          157400            32900          40.0   CT5 2BQ
#
#      prop_lat  prop_lon  Centre_lat  Centre_lon
# 0    51.71151  -1.07196   51.753651   -1.276126
# 1    51.78252  -1.26003   51.753651   -1.276126
# 2    51.78994  -1.27929   51.753651   -1.276126
# 3    51.71269  -1.15480   51.753651   -1.276126
# 4    51.80730  -1.13764   51.753651   -1.276126
# ..        ...       ...         ...         ...
# 109  51.17974   0.98949   51.279643    1.069773
# 110  51.15305   1.11054   51.279643    1.069773
# 111  51.26407   1.26608   51.279643    1.069773
# 112  51.27362   1.21476   51.279643    1.069773
# 113  51.36445   1.03738   51.279643    1.069773
#
# [114 rows x 21 columns]

# %%
import math
import geopy
from geopy import distance

# %% [raw]
# updated_housing_data1['dis_to_cen'] = updated_housing_data1.apply(lambda row: haversine(row['prop_lat'], row['prop_lon'], row['Centre_lat'], row['Centre_lon']), axis=1)

# %%
updated_housing_data1['dis_to_cen(miles)'] = updated_housing_data1.apply(lambda row: geopy.distance.distance((row['prop_lat'], row['prop_lon']), (row['Centre_lat'], row['Centre_lon'])).miles, axis=1)

# %%
updated_housing_data1
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1        1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2        1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3        1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4        1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..                ...                                                ...
# 109      1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 110      1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 111      1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 112      1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 113      1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href    price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000       4
# 1    https://search.savills.com/property-detail/gbs...  1600000       5
# 2    https://search.savills.com/property-detail/gbs...  1050000       5
# 3    https://search.savills.com/property-detail/gbs...   900000       5
# 4    https://search.savills.com/property-detail/gbs...  1300000       5
# ..                                                 ...      ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000       5
# 110  https://search.savills.com/com/en/property-det...   850000       4
# 111  https://search.savills.com/com/en/property-det...  1000000       4
# 112  https://search.savills.com/com/en/property-det...   750000       4
# 113  https://search.savills.com/com/en/property-det...  2950000       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  ...        City  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  ...      Oxford
# 1                    Oxford, Oxfordshire, OX2 7QB   C  ...      Oxford
# 2                    Oxford, Oxfordshire, OX2 8HX   E  ...      Oxford
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  ...      Oxford
# 4                   Oxford, Oxfordshire, OX33 1AY   D  ...      Oxford
# ..                                            ...  ..  ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  ...  Canterbury
# 110              Elham, Canterbury, Kent, CT4 6TE   F  ...  Canterbury
# 111             Staple, Canterbury, Kent, CT3 1NX   C  ...  Canterbury
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  ...  Canterbury
# 113                     Whitstable, Kent, CT5 2BQ   C  ...  Canterbury
#
#     City_population City_med_income  City_med_age  postcode  prop_lat  \
# 0            182100           38800          30.0  OX44 7JG  51.71151
# 1            182100           38800          30.0   OX2 7QB  51.78252
# 2            182100           38800          30.0   OX2 8HX  51.78994
# 3            182100           38800          30.0  OX44 9DJ  51.71269
# 4            182100           38800          30.0  OX33 1AY  51.80730
# ..              ...             ...           ...       ...       ...
# 109          157400           32900          40.0  TN25 5JE  51.17974
# 110          157400           32900          40.0   CT4 6TE  51.15305
# 111          157400           32900          40.0   CT3 1NX  51.26407
# 112          157400           32900          40.0   CT3 1BJ  51.27362
# 113          157400           32900          40.0   CT5 2BQ  51.36445
#
#     prop_lon  Centre_lat  Centre_lon  dis_to_cen(miles)
# 0   -1.07196   51.753651   -1.276126           9.236050
# 1   -1.26003   51.753651   -1.276126           2.111908
# 2   -1.27929   51.753651   -1.276126           2.512517
# 3   -1.15480   51.753651   -1.276126           5.928349
# 4   -1.13764   51.753651   -1.276126           7.001786
# ..       ...         ...         ...                ...
# 109  0.98949   51.279643    1.069773           7.735459
# 110  1.11054   51.279643    1.069773           8.928415
# 111  1.26608   51.279643    1.069773           8.580346
# 112  1.21476   51.279643    1.069773           6.300256
# 113  1.03738   51.279643    1.069773           6.028330
#
# [114 rows x 22 columns]

# %%
updated_housing_data1 = updated_housing_data1.astype({'price':'float'})
updated_housing_data1 = updated_housing_data1.astype({'property_type':'str'})
updated_housing_data1 = updated_housing_data1.astype({'address':'str'})
updated_housing_data1 = updated_housing_data1.astype({'EPC':'str'})
updated_housing_data1 = updated_housing_data1.astype({'sqft':'float'})
updated_housing_data1 = updated_housing_data1.astype({'price_sqft':'str'})
updated_housing_data1 = updated_housing_data1.astype({'City':'str'})
updated_housing_data1 = updated_housing_data1.astype({'property_type':'str'})

# %%
final_housing_data = updated_housing_data1.copy()

# %%
final_housing_data.dtypes
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# listing_link-href         object
# price                    float64
# no_bed                     int64
# no_bath                    int64
# no_rec                     int64
# property_type             object
# address                   object
# EPC                       object
# sqft                     float64
# price_sqft                object
# City                      object
# City_population            int64
# City_med_income            int64
# City_med_age             float64
# postcode                  object
# prop_lat                 float64
# prop_lon                 float64
# Centre_lat               float64
# Centre_lon               float64
# dis_to_cen(miles)        float64
# dtype: object

# %%
final_housing_data.to_excel("final_housing_data.xlsx")

# %%
final_housing_data
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1710807522-1  https://search.savills.com/list?SearchList=Id_...
# 1        1710807524-2  https://search.savills.com/list?SearchList=Id_...
# 2        1710807526-3  https://search.savills.com/list?SearchList=Id_...
# 3        1710807528-4  https://search.savills.com/list?SearchList=Id_...
# 4        1710807530-5  https://search.savills.com/list?SearchList=Id_...
# ..                ...                                                ...
# 109      1710857925-3  https://search.savills.com/com/en/list?SearchL...
# 110      1710857928-4  https://search.savills.com/com/en/list?SearchL...
# 111      1710857931-5  https://search.savills.com/com/en/list?SearchL...
# 112      1710857933-6  https://search.savills.com/com/en/list?SearchL...
# 113      1710857936-7  https://search.savills.com/com/en/list?SearchL...
#
#                                      listing_link-href      price  no_bed  \
# 0    https://search.savills.com/property-detail/gbs...  1500000.0       4
# 1    https://search.savills.com/property-detail/gbs...  1600000.0       5
# 2    https://search.savills.com/property-detail/gbs...  1050000.0       5
# 3    https://search.savills.com/property-detail/gbs...   900000.0       5
# 4    https://search.savills.com/property-detail/gbs...  1300000.0       5
# ..                                                 ...        ...     ...
# 109  https://search.savills.com/com/en/property-det...  1200000.0       5
# 110  https://search.savills.com/com/en/property-det...   850000.0       4
# 111  https://search.savills.com/com/en/property-det...  1000000.0       4
# 112  https://search.savills.com/com/en/property-det...   750000.0       4
# 113  https://search.savills.com/com/en/property-det...  2950000.0       5
#
#      no_bath  no_rec property_type  \
# 0          4       3         House
# 1          3       2         House
# 2          2       4         House
# 3          2       2         House
# 4          4       2         House
# ..       ...     ...           ...
# 109        3       2         House
# 110        2       3         House
# 111        2       3         House
# 112        2       2         House
# 113        5       4         House
#
#                                           address EPC  ...        City  \
# 0    Great Haseley, Oxford, Oxfordshire, OX44 7JG   D  ...      Oxford
# 1                    Oxford, Oxfordshire, OX2 7QB   C  ...      Oxford
# 2                    Oxford, Oxfordshire, OX2 8HX   E  ...      Oxford
# 3       Garsington, Oxford, Oxfordshire, OX44 9DJ   D  ...      Oxford
# 4                   Oxford, Oxfordshire, OX33 1AY   D  ...      Oxford
# ..                                            ...  ..  ...         ...
# 109         Hastingleigh, Ashford, Kent, TN25 5JE   D  ...  Canterbury
# 110              Elham, Canterbury, Kent, CT4 6TE   F  ...  Canterbury
# 111             Staple, Canterbury, Kent, CT3 1NX   C  ...  Canterbury
# 112            Wingham, Canterbury, Kent, CT3 1BJ   E  ...  Canterbury
# 113                     Whitstable, Kent, CT5 2BQ   C  ...  Canterbury
#
#     City_population City_med_income  City_med_age  postcode  prop_lat  \
# 0            182100           38800          30.0  OX44 7JG  51.71151
# 1            182100           38800          30.0   OX2 7QB  51.78252
# 2            182100           38800          30.0   OX2 8HX  51.78994
# 3            182100           38800          30.0  OX44 9DJ  51.71269
# 4            182100           38800          30.0  OX33 1AY  51.80730
# ..              ...             ...           ...       ...       ...
# 109          157400           32900          40.0  TN25 5JE  51.17974
# 110          157400           32900          40.0   CT4 6TE  51.15305
# 111          157400           32900          40.0   CT3 1NX  51.26407
# 112          157400           32900          40.0   CT3 1BJ  51.27362
# 113          157400           32900          40.0   CT5 2BQ  51.36445
#
#     prop_lon  Centre_lat  Centre_lon  dis_to_cen(miles)
# 0   -1.07196   51.753651   -1.276126           9.236050
# 1   -1.26003   51.753651   -1.276126           2.111908
# 2   -1.27929   51.753651   -1.276126           2.512517
# 3   -1.15480   51.753651   -1.276126           5.928349
# 4   -1.13764   51.753651   -1.276126           7.001786
# ..       ...         ...         ...                ...
# 109  0.98949   51.279643    1.069773           7.735459
# 110  1.11054   51.279643    1.069773           8.928415
# 111  1.26608   51.279643    1.069773           8.580346
# 112  1.21476   51.279643    1.069773           6.300256
# 113  1.03738   51.279643    1.069773           6.028330
#
# [114 rows x 22 columns]

# %% [markdown]
# ### Visualisation

# %%
# !pip install hvplot
import matplotlib.pyplot as plt
import seaborn as sns
# import hvplot.pandas
from scipy.stats import norm
from scipy import stats
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize = ( 10 , 6 ))
sns.histplot(updated_housing_data['price'])
ax.set_xlabel('Price (MM Pounds)')
plt.ylabel("Count")
plt.grid()
plt.show()

# %%
updated_housing_data['price'].describe()
# Out:
# count    1.140000e+02
# mean     1.656446e+06
# std      1.207453e+06
# min      2.000000e+05
# 25%      9.125000e+05
# 50%      1.337500e+06
# 75%      1.990000e+06
# max      8.250000e+06
# Name: price, dtype: float64

# %%
#histogram and normal probability plot
sns.distplot(updated_housing_data['price'], fit=norm)
fig = plt.figure()
res = stats.probplot(updated_housing_data['price'], plot=plt)
# Out:
# /var/folders/86/jy_sl6ds7qs5g0c8z5lq2v1h0000gn/T/ipykernel_66552/3932488054.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(updated_housing_data['price'], fit=norm)
